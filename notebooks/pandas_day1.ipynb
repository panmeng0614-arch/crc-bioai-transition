# %%
import pandas as pd

# %%
data = {
    "patient": ["P001","P002","P003","P004","P005"],
    "condition": ["Normal", "Adenoma", "CRC", "Adenoma","CRC"],
    "age": [45, 58, 63, 52, 67]
}

df = pd.DataFrame(data)

print(df)
# Out:
#   patient condition  age
# 0    P001    Normal   45
# 1    P002   Adenoma   58
# 2    P003       CRC   63
# 3    P004   Adenoma   52
# 4    P005       CRC   67

# %%
df.head()
# Out:
#   patient condition  age
# 0    P001    Normal   45
# 1    P002   Adenoma   58
# 2    P003       CRC   63
# 3    P004   Adenoma   52
# 4    P005       CRC   67

# %%
df.shape
# Out:
# (5, 3)

# %%
df.columns
# Out:
# Index(['patient', 'condition', 'age'], dtype='str')

# %%
df["patient"]
# Out:
# 0    P001
# 1    P002
# 2    P003
# 3    P004
# 4    P005
# Name: patient, dtype: str

# %%
df["condition"]
# Out:
# 0     Normal
# 1    Adenoma
# 2        CRC
# 3    Adenoma
# 4        CRC
# Name: condition, dtype: str

# %%
df["age"]
# Out:
# 0    45
# 1    58
# 2    63
# 3    52
# 4    67
# Name: age, dtype: int64

# %%
df["condition"] == "CRC"
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# Name: condition, dtype: bool

# %%
crc_df = df[df["condition"] == "CRC"]
print(crc_df)
# Out:
#   patient condition  age
# 2    P003       CRC   63
# 4    P005       CRC   67

# %%
adenoma_df = df[df["condition"] == "Adenoma"]
print(adenoma_df)
# Out:
#   patient condition  age
# 1    P002   Adenoma   58
# 3    P004   Adenoma   52

# %%
old_df = df[df["age"] >= 60]
print(old_df)
# Out:
#   patient condition  age
# 2    P003       CRC   63
# 4    P005       CRC   67

# %%
df["condition"].value_counts()
# Out:
# condition
# Adenoma    2
# CRC        2
# Normal     1
# Name: count, dtype: int64

# %%
df["age"].value_counts()
# Out:
# age
# 45    1
# 58    1
# 63    1
# 52    1
# 67    1
# Name: count, dtype: int64

# %%
metadata = {
    "patient": ["P101", "P102","P103","P104", "P105", "P106"],
    "condition": ["Normal", "Normal", "Adenoma", "Adenoma", "CRC", "CRC"],
    "age": [42, 51, 55, 61, 65, 70]
}

df = pd.DataFrame(metadata)

print(df)

# %%
df.head()

# %%
df.shape

# %%
df["condition"]

# %%
crc_df = df[df["condition"] == "CRC"]
print(crc_df)

# %%
old_df = df[df["age"] >= 60]
print(old_df)

# %%
df["condition"].value_counts()
