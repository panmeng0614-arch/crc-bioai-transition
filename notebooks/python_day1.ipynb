# %%
print("hello bioai")
# Out:
# hello bioai

# %%
patient = "P002"
age = 65
condition = "CRC"

print(patient)
print(age)
print(condition)
# Out:
# P002
# 65
# CRC

# %%
sample = "A001"
stage = "adenoma"

print(sample)
print(stage)
# Out:
# A001
# adenoma

# %%
patient = "A002"
age = 55
tumor_size = 2.7
is_crc = True

print(type(patient))
print(type(age))
print(type(tumor_size))
print(type(is_crc))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
sample = "C001"
year = 2006
expression = 3.47
has_tumor = False

print(type(sample))
print(type(year))
print(type(expression))
print(type(has_tumor))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
patient = "D001"
print(patient)
# Out:
# D001

# %%
age = 55
print(age)
# Out:
# 55

# %%
print("CRC")
# Out:
# CRC

# %%
patients = ["A001","A002","A003"]
print(patients)
# Out:
# ['A001', 'A002', 'A003']

# %%
conditions = ["adenoma","Normal","CRC"]
print(conditions)
# Out:
# ['adenoma', 'Normal', 'CRC']

# %%
ages = [45,56,67]
print(ages)
# Out:
# [45, 56, 67]

# %%
patients = ["P001","P002","P003"]
print(patients[0])
# Out:
# P001

# %%
conditions = ["Normal","Adenoma","CRC"]
print(conditions[0])
print(conditions[1])
print(conditions[2])
# Out:
# Normal
# Adenoma
# CRC

# %%
patients = ["P001","P002","P003"]

for patient in patients:
    print(patient)
# Out:
# P001
# P002
# P003

# %%
conditions = ["Normal","adenoma","crc"]

for condition in conditions:
    print(condition)
# Out:
# Normal
# adenoma
# crc

# %%
patient = "C001"
condition = "crc"
age = 62

print(patient)
print(condition)
print(age)
# Out:
# C001
# crc
# 62

# %%
samples = ["N001","N002","N003"]

for sample in samples:
    print(sample)
# Out:
# N001
# N002
# N003

# %%
samples = ["P001","P002","P003"]

print(samples[0])
print(samples[1])
print(samples[2])
# Out:
# P001
# P002
# P003

# %%
patients = ["A001","A002","A003"]

for patient in patients:
    print("Current patient:")
    print(patient)
# Out:
# Current patient:
# A001
# Current patient:
# A002
# Current patient:
# A003
