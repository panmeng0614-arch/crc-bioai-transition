# %%
group_a = [9, 10, 10, 10, 11]
group_b = [1, 5, 10, 15, 19]

import statistics

print(statistics.mean(group_a))
print(statistics.mean(group_b))
# Out:
# 10
# 10

# %%
import matplotlib.pyplot as plt

values = [5, 6, 5, 7, 6, 8, 6, 5, 20]

plt.hist(values)
plt.xlabel("Expression")
plt.ylabel("Frequency")
plt.title("Distribution of gene expression")

plt.show()

# %%
values1 = [10, 11, 12, 9, 10, 11, 12]
values2 = [10, 11, 12, 9, 10, 11, 12, 45]

statistics.mean(values1)
# Out:
# 10.714285714285714

# %%
statistics.median(values1)
# Out:
# 11

# %%
statistics.mean(values2)
# Out:
# 15

# %%
statistics.median(values2)
# Out:
# 11.0

# %%
import math

values = [1, 10, 100, 1000, 10000]

for value in values:
    print(math.log10(value))
# Out:
# 0.0
# 1.0
# 2.0
# 3.0
# 4.0
